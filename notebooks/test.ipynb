# %% [markdown]
# object detection only

# %%
import cv2
from ultralytics import YOLO
import numpy as np

# Load your trained model
model = YOLO(r'E:\elevatetrsest\CamEDGE counting\bestv2.pt')

def detect_warehouse_video(video_path, output_path=None, conf_threshold=0.5):
    """
    Detect objects in warehouse video and count them
    
    Args:
        video_path: Path to input video
        output_path: Path to save output video (optional)
        conf_threshold: Confidence threshold for detections
    """
    
    # Open video
    cap = cv2.VideoCapture(video_path)
    
    if output_path:
        # Get video properties
        fps = int(cap.get(cv2.CAP_PROP_FPS))
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        
        # Create video writer
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
    
    frame_count = 0
    total_detections = {}
    
    while True:
        ret, frame = cap.read()
        if not ret:
            break
            
        frame_count += 1
        
        # Run detection
        results = model(frame, conf=conf_threshold)
        
        # Process results
        frame_detections = {}
        for result in results:
            if result.boxes is not None:
                for box in result.boxes:
                    class_id = int(box.cls)
                    class_name = model.names[class_id]
                    confidence = float(box.conf)
                    
                    # Count detections
                    frame_detections[class_name] = frame_detections.get(class_name, 0) + 1
                    total_detections[class_name] = total_detections.get(class_name, 0) + 1
        
        # Draw results on frame
        annotated_frame = results[0].plot()
        
        # Add count text
        y_offset = 30
        for class_name, count in frame_detections.items():
            cv2.putText(annotated_frame, f"{class_name}: {count}", 
                       (10, y_offset), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
            y_offset += 25
        
        # Save frame if output specified
        if output_path:
            out.write(annotated_frame)
        
        # Display frame (optional - comment out for headless)
        cv2.imshow('Warehouse Detection', annotated_frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
        
        # Print progress every 100 frames
        if frame_count % 100 == 0:
            print(f"Processed {frame_count} frames - Current detections: {frame_detections}")
    
    # Cleanup
    cap.release()
    if output_path:
        out.release()
    cv2.destroyAllWindows()
    
    print(f"\n🎉 Video processing complete!")
    print(f"📝 Total frames processed: {frame_count}")
    print(f"📊 Total object detections: {total_detections}")
    
    return total_detections

# Usage examples:
print("🚀 Warehouse Video Detection System Ready!")
print("\n📝 Usage:")
print("1. Process video and display: detect_warehouse_video('warehouse_video.mp4')")
print("2. Process and save output: detect_warehouse_video('input.mp4', 'output.mp4')")
print("3. With custom confidence: detect_warehouse_video('video.mp4', conf_threshold=0.6)")

# Example usage:
# detections = detect_warehouse_video('your_warehouse_video.mp4', 'output_with_detections.mp4')
# Out:
# 🚀 Warehouse Video Detection System Ready!
#
# 📝 Usage:
# 1. Process video and display: detect_warehouse_video('warehouse_video.mp4')
# 2. Process and save output: detect_warehouse_video('input.mp4', 'output.mp4')
# 3. With custom confidence: detect_warehouse_video('video.mp4', conf_threshold=0.6)

# %%
# Process warehouse video
detections = detect_warehouse_video(r'E:\elevatetrsest\CamEDGE counting\test12_warehouse.mp4', 'output12.mp4')
# Out:
# 0: 384x640 4 boxs, 2 persons, 309.3ms
# Speed: 4.4ms preprocess, 309.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 person, 37.8ms
# Speed: 1.1ms preprocess, 37.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 38.0ms
# Speed: 1.1ms preprocess, 38.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.3ms
# Speed: 1.7ms preprocess, 35.3ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.3ms
# Speed: 1.3ms preprocess, 35.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.3ms
# Speed: 2.0ms preprocess, 35.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.6ms
# Speed: 1.3ms preprocess, 35.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.5ms
# Speed: 3.0ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 1 person, 35.3ms
# Speed: 1.4ms preprocess, 35.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 1 person, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 pallets, 1 person, 35.8ms
# Speed: 1.3ms preprocess, 35.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 1 pallets, 1 person, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 1 pallets, 1 person, 35.7ms
# Speed: 2.9ms preprocess, 35.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 pallets, 1 person, 35.6ms
# Speed: 1.5ms preprocess, 35.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 pallets, 2 persons, 35.5ms
# Speed: 1.2ms preprocess, 35.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 pallets, 2 persons, 35.5ms
# Speed: 1.2ms preprocess, 35.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 35.4ms
# Speed: 1.2ms preprocess, 35.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 35.3ms
# Speed: 1.2ms preprocess, 35.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 37.9ms
# Speed: 1.5ms preprocess, 37.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 35.5ms
# Speed: 1.8ms preprocess, 35.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 35.5ms
# Speed: 2.0ms preprocess, 35.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 35.8ms
# Speed: 2.7ms preprocess, 35.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 35.5ms
# Speed: 1.3ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 35.4ms
# Speed: 1.7ms preprocess, 35.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.3ms
# Speed: 1.4ms preprocess, 35.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 1 person, 35.4ms
# Speed: 1.2ms preprocess, 35.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.4ms
# Speed: 1.2ms preprocess, 35.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 pallets, 1 person, 35.4ms
# Speed: 1.4ms preprocess, 35.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 forklift, 1 pallets, 1 person, 35.4ms
# Speed: 1.3ms preprocess, 35.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 pallets, 1 person, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 pallets, 1 person, 35.5ms
# Speed: 1.3ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pallets, 1 person, 35.4ms
# Speed: 1.2ms preprocess, 35.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 1 pallets, 2 persons, 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 2 persons, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 2 persons, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 forklifts, 2 persons, 35.6ms
# Speed: 2.1ms preprocess, 35.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 3 forklifts, 1 pallets, 3 persons, 36.1ms
# Speed: 1.1ms preprocess, 36.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 3 forklifts, 1 person, 35.6ms
# Speed: 1.3ms preprocess, 35.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 forklifts, 1 pallets, 2 persons, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 forklift, 1 pallets, 1 person, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 1 pallets, 2 persons, 35.5ms
# Speed: 1.3ms preprocess, 35.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 1 pallets, 2 persons, 35.4ms
# Speed: 1.9ms preprocess, 35.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 forklifts, 1 pallets, 2 persons, 36.0ms
# Speed: 1.5ms preprocess, 36.0ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 pallets, 1 person, 35.5ms
# Speed: 2.5ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 pallets, 3 persons, 35.6ms
# Speed: 1.3ms preprocess, 35.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 pallets, 1 person, 35.6ms
# Speed: 1.3ms preprocess, 35.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 pallets, 1 person, 35.6ms
# Speed: 1.7ms preprocess, 35.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.5ms
# Speed: 1.5ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 2 persons, 35.3ms
# Speed: 1.4ms preprocess, 35.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 2 persons, 35.4ms
# Speed: 1.4ms preprocess, 35.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 2 persons, 35.3ms
# Speed: 1.0ms preprocess, 35.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 2 persons, 35.5ms
# Speed: 1.3ms preprocess, 35.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 35.5ms
# Speed: 1.6ms preprocess, 35.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 37.5ms
# Speed: 1.4ms preprocess, 37.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 35.3ms
# Speed: 1.0ms preprocess, 35.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 35.3ms
# Speed: 1.3ms preprocess, 35.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 35.5ms
# Speed: 1.3ms preprocess, 35.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 2 persons, 35.5ms
# Speed: 1.5ms preprocess, 35.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 2 persons, 35.6ms
# Speed: 1.5ms preprocess, 35.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 2 persons, 35.7ms
# Speed: 1.2ms preprocess, 35.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 35.7ms
# Speed: 1.3ms preprocess, 35.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 2 persons, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 35.8ms
# Speed: 1.1ms preprocess, 35.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 2 persons, 35.6ms
# Speed: 1.8ms preprocess, 35.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.4ms
# Speed: 1.6ms preprocess, 35.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 35.6ms
# Speed: 1.4ms preprocess, 35.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 36.0ms
# Speed: 1.5ms preprocess, 36.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 2 persons, 35.5ms
# Speed: 1.4ms preprocess, 35.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 35.4ms
# Speed: 1.2ms preprocess, 35.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 35.5ms
# Speed: 1.3ms preprocess, 35.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 person, 36.3ms
# Speed: 1.3ms preprocess, 36.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 35.4ms
# Speed: 1.5ms preprocess, 35.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 35.6ms
# Speed: 1.4ms preprocess, 35.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.6ms
# Speed: 1.6ms preprocess, 35.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.5ms
# Speed: 1.2ms preprocess, 35.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 35.5ms
# Speed: 1.3ms preprocess, 35.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 forklift, 2 persons, 35.5ms
# Speed: 2.0ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 3 persons, 35.5ms
# Speed: 1.5ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 36.6ms
# Speed: 1.2ms preprocess, 36.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 35.6ms
# Speed: 1.2ms preprocess, 35.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 35.6ms
# Speed: 1.2ms preprocess, 35.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 boxs, 35.4ms
# Speed: 1.2ms preprocess, 35.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 boxs, 2 persons, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 boxs, 2 persons, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 2 persons, 35.7ms
# Speed: 1.5ms preprocess, 35.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 2 persons, 35.6ms
# Speed: 1.0ms preprocess, 35.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 2 persons, 35.5ms
# Speed: 1.7ms preprocess, 35.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 35.4ms
# Speed: 1.4ms preprocess, 35.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 35.3ms
# Speed: 1.1ms preprocess, 35.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 3 persons, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 3 persons, 35.4ms
# Speed: 1.3ms preprocess, 35.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 3 persons, 35.8ms
# Speed: 2.1ms preprocess, 35.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 35.3ms
# Speed: 1.1ms preprocess, 35.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 3 persons, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed 100 frames - Current detections: {'box': 3, 'person': 3}
#
# 0: 384x640 3 boxs, 2 persons, 35.8ms
# Speed: 1.7ms preprocess, 35.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 35.6ms
# Speed: 1.3ms preprocess, 35.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 35.8ms
# Speed: 1.4ms preprocess, 35.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 35.5ms
# Speed: 1.2ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 35.7ms
# Speed: 1.6ms preprocess, 35.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 2 persons, 36.9ms
# Speed: 1.1ms preprocess, 36.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 35.6ms
# Speed: 1.5ms preprocess, 35.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 2 persons, 35.5ms
# Speed: 1.4ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 2 persons, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 2 persons, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 35.7ms
# Speed: 1.3ms preprocess, 35.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 35.8ms
# Speed: 2.5ms preprocess, 35.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 35.5ms
# Speed: 1.2ms preprocess, 35.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 3 persons, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 2 persons, 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 3 persons, 35.4ms
# Speed: 1.2ms preprocess, 35.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 35.4ms
# Speed: 1.7ms preprocess, 35.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 3 persons, 35.6ms
# Speed: 1.2ms preprocess, 35.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 3 persons, 35.6ms
# Speed: 1.6ms preprocess, 35.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 35.6ms
# Speed: 1.7ms preprocess, 35.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 3 persons, 37.7ms
# Speed: 1.2ms preprocess, 37.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 2 persons, 35.5ms
# Speed: 1.2ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 2 persons, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 2 persons, 35.8ms
# Speed: 1.7ms preprocess, 35.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 2 persons, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 2 persons, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 2 persons, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 2 persons, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.7ms
# Speed: 1.0ms preprocess, 35.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 1 person, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 1 person, 35.4ms
# Speed: 1.5ms preprocess, 35.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 1 person, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 1 person, 35.6ms
# Speed: 1.2ms preprocess, 35.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 2 forklifts, 1 person, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 1 person, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 person, 36.6ms
# Speed: 1.3ms preprocess, 36.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 person, 35.7ms
# Speed: 1.1ms preprocess, 35.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 1 person, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 person, 35.6ms
# Speed: 1.5ms preprocess, 35.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 person, 35.5ms
# Speed: 1.5ms preprocess, 35.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 person, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 person, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.6ms
# Speed: 1.0ms preprocess, 35.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 person, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.4ms
# Speed: 1.3ms preprocess, 35.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 1 person, 35.7ms
# Speed: 1.2ms preprocess, 35.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 person, 35.7ms
# Speed: 1.0ms preprocess, 35.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 1 person, 36.9ms
# Speed: 1.3ms preprocess, 36.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 1 person, 35.6ms
# Speed: 1.3ms preprocess, 35.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 person, 35.5ms
# Speed: 1.4ms preprocess, 35.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 35.4ms
# Speed: 1.2ms preprocess, 35.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 35.6ms
# Speed: 1.3ms preprocess, 35.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 35.5ms
# Speed: 1.2ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.4ms
# Speed: 1.3ms preprocess, 35.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.3ms
# Speed: 1.1ms preprocess, 35.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.5ms
# Speed: 1.2ms preprocess, 35.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.3ms
# Speed: 1.1ms preprocess, 35.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.6ms
# Speed: 1.3ms preprocess, 35.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.6ms
# Speed: 1.7ms preprocess, 35.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 36.8ms
# Speed: 2.0ms preprocess, 36.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.5ms
# Speed: 1.2ms preprocess, 35.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.4ms
# Speed: 1.3ms preprocess, 35.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.4ms
# Speed: 1.3ms preprocess, 35.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.4ms
# Speed: 1.3ms preprocess, 35.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.7ms
# Speed: 1.1ms preprocess, 35.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.9ms
# Speed: 1.5ms preprocess, 35.9ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.6ms
# Speed: 1.5ms preprocess, 35.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.9ms
# Speed: 1.3ms preprocess, 35.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.7ms
# Speed: 1.1ms preprocess, 35.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.5ms
# Speed: 1.2ms preprocess, 35.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.7ms
# Speed: 1.4ms preprocess, 35.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.6ms
# Speed: 2.0ms preprocess, 35.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.7ms
# Speed: 1.2ms preprocess, 35.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.5ms
# Speed: 2.0ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.3ms
# Speed: 1.0ms preprocess, 35.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 37.3ms
# Speed: 1.5ms preprocess, 37.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.4ms
# Speed: 1.2ms preprocess, 35.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 35.5ms
# Speed: 1.2ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.9ms
# Speed: 1.2ms preprocess, 35.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.5ms
# Speed: 1.3ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed 200 frames - Current detections: {'person': 1, 'box': 2}
#
# 0: 384x640 1 box, 1 person, 35.6ms
# Speed: 1.8ms preprocess, 35.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 person, 35.6ms
# Speed: 1.5ms preprocess, 35.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.7ms
# Speed: 1.3ms preprocess, 35.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.5ms
# Speed: 1.7ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.7ms
# Speed: 1.2ms preprocess, 35.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.8ms
# Speed: 1.4ms preprocess, 35.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.8ms
# Speed: 1.0ms preprocess, 35.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 36.3ms
# Speed: 1.1ms preprocess, 36.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.5ms
# Speed: 1.2ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 35.6ms
# Speed: 2.3ms preprocess, 35.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 35.8ms
# Speed: 1.2ms preprocess, 35.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.4ms
# Speed: 1.8ms preprocess, 35.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 35.4ms
# Speed: 1.4ms preprocess, 35.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.5ms
# Speed: 1.5ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.7ms
# Speed: 1.4ms preprocess, 35.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.7ms
# Speed: 1.2ms preprocess, 35.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.3ms
# Speed: 1.0ms preprocess, 35.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 35.4ms
# Speed: 1.3ms preprocess, 35.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 36.0ms
# Speed: 1.2ms preprocess, 36.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.5ms
# Speed: 1.2ms preprocess, 35.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.4ms
# Speed: 1.3ms preprocess, 35.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.5ms
# Speed: 1.6ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.4ms
# Speed: 1.6ms preprocess, 35.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.4ms
# Speed: 1.5ms preprocess, 35.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.3ms
# Speed: 1.1ms preprocess, 35.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.4ms
# Speed: 1.4ms preprocess, 35.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.7ms
# Speed: 1.2ms preprocess, 35.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 35.5ms
# Speed: 1.8ms preprocess, 35.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 38.9ms
# Speed: 2.8ms preprocess, 38.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.4ms
# Speed: 1.6ms preprocess, 35.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.7ms
# Speed: 1.1ms preprocess, 35.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.5ms
# Speed: 1.3ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.7ms
# Speed: 1.1ms preprocess, 35.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.7ms
# Speed: 1.1ms preprocess, 35.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.5ms
# Speed: 1.3ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.6ms
# Speed: 1.0ms preprocess, 35.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.4ms
# Speed: 1.2ms preprocess, 35.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 35.3ms
# Speed: 1.1ms preprocess, 35.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 38.1ms
# Speed: 1.2ms preprocess, 38.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.6ms
# Speed: 1.5ms preprocess, 35.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.6ms
# Speed: 1.8ms preprocess, 35.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.4ms
# Speed: 1.2ms preprocess, 35.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.4ms
# Speed: 1.2ms preprocess, 35.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.6ms
# Speed: 1.3ms preprocess, 35.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 35.7ms
# Speed: 1.2ms preprocess, 35.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.7ms
# Speed: 1.0ms preprocess, 35.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.4ms
# Speed: 1.2ms preprocess, 35.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.6ms
# Speed: 1.0ms preprocess, 35.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.7ms
# Speed: 1.2ms preprocess, 35.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 35.6ms
# Speed: 1.7ms preprocess, 35.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 37.3ms
# Speed: 2.3ms preprocess, 37.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 35.4ms
# Speed: 1.2ms preprocess, 35.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 35.4ms
# Speed: 1.5ms preprocess, 35.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 35.6ms
# Speed: 1.2ms preprocess, 35.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 pallets, 35.3ms
# Speed: 1.1ms preprocess, 35.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 35.5ms
# Speed: 1.3ms preprocess, 35.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 pallets, 35.5ms
# Speed: 1.2ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 35.6ms
# Speed: 1.0ms preprocess, 35.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 35.5ms
# Speed: 1.2ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 35.7ms
# Speed: 1.1ms preprocess, 35.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 35.7ms
# Speed: 1.3ms preprocess, 35.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 35.6ms
# Speed: 1.0ms preprocess, 35.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 35.6ms
# Speed: 1.0ms preprocess, 35.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 35.7ms
# Speed: 1.0ms preprocess, 35.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 35.5ms
# Speed: 1.5ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 35.6ms
# Speed: 1.5ms preprocess, 35.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 37.5ms
# Speed: 1.1ms preprocess, 37.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 35.5ms
# Speed: 2.0ms preprocess, 35.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed 300 frames - Current detections: {'box': 1, 'forklift': 1}
#
# 0: 384x640 1 box, 1 forklift, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 35.6ms
# Speed: 1.2ms preprocess, 35.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 35.7ms
# Speed: 1.3ms preprocess, 35.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 35.5ms
# Speed: 1.5ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 35.5ms
# Speed: 1.3ms preprocess, 35.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 35.8ms
# Speed: 1.2ms preprocess, 35.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 35.9ms
# Speed: 1.2ms preprocess, 35.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 35.7ms
# Speed: 1.4ms preprocess, 35.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 35.4ms
# Speed: 1.2ms preprocess, 35.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 35.7ms
# Speed: 1.1ms preprocess, 35.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 35.5ms
# Speed: 1.2ms preprocess, 35.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 35.7ms
# Speed: 1.5ms preprocess, 35.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 37.9ms
# Speed: 1.1ms preprocess, 37.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.6ms
# Speed: 1.0ms preprocess, 35.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.9ms
# Speed: 1.2ms preprocess, 35.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.7ms
# Speed: 2.0ms preprocess, 35.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.7ms
# Speed: 1.6ms preprocess, 35.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.6ms
# Speed: 1.0ms preprocess, 35.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.6ms
# Speed: 1.5ms preprocess, 35.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.6ms
# Speed: 1.4ms preprocess, 35.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.7ms
# Speed: 1.1ms preprocess, 35.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.7ms
# Speed: 1.1ms preprocess, 35.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.8ms
# Speed: 1.1ms preprocess, 35.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.5ms
# Speed: 1.4ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.5ms
# Speed: 1.7ms preprocess, 35.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.6ms
# Speed: 1.2ms preprocess, 35.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.5ms
# Speed: 1.2ms preprocess, 35.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.4ms
# Speed: 2.0ms preprocess, 35.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.6ms
# Speed: 1.5ms preprocess, 35.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.6ms
# Speed: 1.7ms preprocess, 35.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.6ms
# Speed: 2.3ms preprocess, 35.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 1 pallets, 1 person, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.7ms
# Speed: 1.2ms preprocess, 35.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.5ms
# Speed: 1.3ms preprocess, 35.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.5ms
# Speed: 1.2ms preprocess, 35.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.8ms
# Speed: 1.1ms preprocess, 35.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 36.3ms
# Speed: 1.1ms preprocess, 36.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.4ms
# Speed: 1.2ms preprocess, 35.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.9ms
# Speed: 1.2ms preprocess, 35.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.7ms
# Speed: 1.1ms preprocess, 35.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.7ms
# Speed: 1.8ms preprocess, 35.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 1 person, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 1 person, 35.5ms
# Speed: 1.6ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forklift, 35.4ms
# ...
#
# 0: 384x640 6 boxs, 3 persons, 35.8ms
# Speed: 1.2ms preprocess, 35.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 boxs, 3 persons, 35.6ms
# Speed: 1.0ms preprocess, 35.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 boxs, 2 persons, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 boxs, 3 persons, 35.6ms
# Speed: 1.4ms preprocess, 35.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 boxs, 1 forklift, 3 persons, 38.1ms
# Speed: 1.1ms preprocess, 38.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 boxs, 1 forklift, 2 persons, 35.8ms
# Speed: 1.0ms preprocess, 35.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 boxs, 1 forklift, 2 persons, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 2 forklifts, 2 persons, 35.6ms
# Speed: 1.0ms preprocess, 35.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 1 forklift, 2 persons, 35.7ms
# Speed: 1.1ms preprocess, 35.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 1 forklift, 1 person, 35.6ms
# Speed: 1.6ms preprocess, 35.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 1 forklift, 2 persons, 35.9ms
# Speed: 1.0ms preprocess, 35.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 1 forklift, 2 persons, 35.8ms
# Speed: 1.0ms preprocess, 35.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 1 forklift, 2 persons, 35.8ms
# Speed: 1.1ms preprocess, 35.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 boxs, 1 forklift, 2 persons, 35.7ms
# Speed: 1.3ms preprocess, 35.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 boxs, 1 forklift, 2 persons, 35.8ms
# Speed: 1.0ms preprocess, 35.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 2 persons, 36.0ms
# Speed: 1.8ms preprocess, 36.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 forklift, 2 persons, 35.8ms
# Speed: 1.1ms preprocess, 35.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 boxs, 1 forklift, 2 persons, 35.9ms
# Speed: 1.1ms preprocess, 35.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 1 forklift, 3 persons, 36.0ms
# Speed: 1.0ms preprocess, 36.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 boxs, 1 forklift, 2 persons, 35.7ms
# Speed: 1.1ms preprocess, 35.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 boxs, 1 forklift, 1 person, 35.9ms
# Speed: 1.1ms preprocess, 35.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 boxs, 1 forklift, 2 persons, 36.0ms
# Speed: 1.4ms preprocess, 36.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 1 forklift, 2 persons, 35.8ms
# Speed: 1.1ms preprocess, 35.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 forklift, 1 person, 35.9ms
# Speed: 1.4ms preprocess, 35.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 forklift, 2 persons, 35.6ms
# Speed: 1.3ms preprocess, 35.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 forklift, 2 persons, 35.6ms
# Speed: 1.0ms preprocess, 35.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 boxs, 1 forklift, 1 person, 35.8ms
# Speed: 1.1ms preprocess, 35.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 forklift, 2 persons, 35.7ms
# Speed: 1.0ms preprocess, 35.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 forklift, 1 person, 35.7ms
# Speed: 1.1ms preprocess, 35.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed 2400 frames - Current detections: {'box': 2, 'forklift': 1, 'person': 1}
#
# 0: 384x640 2 boxs, 1 forklift, 2 persons, 35.8ms
# Speed: 1.2ms preprocess, 35.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 2 persons, 36.0ms
# Speed: 1.0ms preprocess, 36.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 forklift, 3 persons, 35.9ms
# Speed: 1.5ms preprocess, 35.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 forklift, 3 persons, 36.0ms
# Speed: 1.1ms preprocess, 36.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 forklift, 2 persons, 35.9ms
# Speed: 1.3ms preprocess, 35.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 forklifts, 2 persons, 35.9ms
# Speed: 1.6ms preprocess, 35.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 forklift, 2 persons, 36.0ms
# Speed: 1.1ms preprocess, 36.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 2 persons, 35.9ms
# Speed: 1.1ms preprocess, 35.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 3 persons, 36.1ms
# Speed: 1.1ms preprocess, 36.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 3 persons, 37.4ms
# Speed: 1.1ms preprocess, 37.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 forklift, 3 persons, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 forklift, 4 persons, 35.6ms
# Speed: 1.0ms preprocess, 35.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 3 persons, 35.6ms
# Speed: 1.0ms preprocess, 35.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 3 persons, 35.8ms
# Speed: 1.1ms preprocess, 35.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 3 persons, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 2 persons, 35.9ms
# Speed: 1.2ms preprocess, 35.9ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 35.8ms
# Speed: 2.8ms preprocess, 35.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 36.3ms
# Speed: 1.0ms preprocess, 36.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.8ms
# Speed: 1.0ms preprocess, 35.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.9ms
# Speed: 1.1ms preprocess, 35.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 person, 35.6ms
# Speed: 1.3ms preprocess, 35.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 forklift, 2 persons, 35.8ms
# Speed: 1.2ms preprocess, 35.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 2 persons, 35.6ms
# Speed: 1.2ms preprocess, 35.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 35.9ms
# Speed: 1.0ms preprocess, 35.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 35.8ms
# Speed: 1.7ms preprocess, 35.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 pallets, 2 persons, 36.0ms
# Speed: 1.1ms preprocess, 36.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 1 pallets, 2 persons, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 boxs, 1 pallets, 2 persons, 35.7ms
# Speed: 1.1ms preprocess, 35.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 boxs, 2 persons, 35.7ms
# Speed: 1.2ms preprocess, 35.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 boxs, 1 pallets, 2 persons, 35.6ms
# Speed: 1.0ms preprocess, 35.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 boxs, 1 pallets, 2 persons, 35.7ms
# Speed: 1.1ms preprocess, 35.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 2 persons, 35.8ms
# Speed: 1.1ms preprocess, 35.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 boxs, 2 persons, 35.9ms
# Speed: 2.3ms preprocess, 35.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 35.9ms
# Speed: 1.3ms preprocess, 35.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 boxs, 2 persons, 36.1ms
# Speed: 1.2ms preprocess, 36.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 boxs, 1 person, 35.8ms
# Speed: 1.8ms preprocess, 35.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 boxs, 1 person, 35.8ms
# Speed: 1.1ms preprocess, 35.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 1 pallets, 1 person, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 1 pallets, 2 persons, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 boxs, 1 pallets, 2 persons, 35.8ms
# Speed: 1.3ms preprocess, 35.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 boxs, 1 forklift, 1 pallets, 2 persons, 35.6ms
# Speed: 1.5ms preprocess, 35.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 boxs, 1 pallets, 1 person, 35.8ms
# Speed: 1.0ms preprocess, 35.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 2 persons, 35.6ms
# Speed: 1.0ms preprocess, 35.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 boxs, 3 persons, 35.7ms
# Speed: 1.4ms preprocess, 35.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 2 persons, 35.8ms
# Speed: 1.7ms preprocess, 35.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 3 persons, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 2 persons, 35.8ms
# Speed: 1.1ms preprocess, 35.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 2 persons, 35.8ms
# Speed: 1.5ms preprocess, 35.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 1 person, 35.7ms
# Speed: 1.1ms preprocess, 35.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 1 person, 35.6ms
# Speed: 1.2ms preprocess, 35.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 35.6ms
# Speed: 1.0ms preprocess, 35.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 2 persons, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 2 persons, 35.9ms
# Speed: 1.1ms preprocess, 35.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 35.5ms
# Speed: 1.3ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 35.9ms
# Speed: 1.5ms preprocess, 35.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 boxs, 2 persons, 35.8ms
# Speed: 1.3ms preprocess, 35.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 2 persons, 35.9ms
# Speed: 1.2ms preprocess, 35.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 box, 2 persons, 35.7ms
# Speed: 1.3ms preprocess, 35.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 35.8ms
# Speed: 1.4ms preprocess, 35.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 1 forklift, 3 persons, 36.2ms
# Speed: 2.0ms preprocess, 36.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 1 forklift, 2 persons, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 1 forklift, 1 person, 35.7ms
# Speed: 1.2ms preprocess, 35.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 boxs, 1 forklift, 1 person, 35.9ms
# Speed: 2.5ms preprocess, 35.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 boxs, 1 forklift, 2 persons, 35.8ms
# Speed: 2.4ms preprocess, 35.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 boxs, 1 forklift, 1 person, 35.6ms
# Speed: 1.2ms preprocess, 35.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 boxs, 1 forklift, 1 person, 35.6ms
# Speed: 1.0ms preprocess, 35.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 boxs, 1 forklift, 2 persons, 35.7ms
# Speed: 1.0ms preprocess, 35.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 boxs, 1 forklift, 1 person, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 boxs, 1 forklift, 1 person, 35.7ms
# Speed: 1.1ms preprocess, 35.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 boxs, 1 forklift, 2 persons, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 boxs, 1 forklift, 2 persons, 35.7ms
# Speed: 1.1ms preprocess, 35.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 boxs, 1 forklift, 2 persons, 36.0ms
# Speed: 2.5ms preprocess, 36.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 boxs, 1 forklift, 2 persons, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 boxs, 1 forklift, 2 persons, 35.9ms
# Speed: 1.2ms preprocess, 35.9ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 boxs, 2 persons, 35.5ms
# Speed: 1.9ms preprocess, 35.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 boxs, 2 persons, 36.9ms
# Speed: 1.1ms preprocess, 36.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 boxs, 2 persons, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 boxs, 3 persons, 35.6ms
# Speed: 1.2ms preprocess, 35.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 boxs, 3 persons, 35.6ms
# Speed: 1.6ms preprocess, 35.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 boxs, 2 persons, 36.0ms
# Speed: 1.4ms preprocess, 36.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 boxs, 2 persons, 36.0ms
# Speed: 2.2ms preprocess, 36.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 🎉 Video processing complete!
# 📝 Total frames processed: 2482
# 📊 Total object detections: {'box': 2481, 'person': 2878, 'pallets': 71, 'forklift': 860}

# %% [markdown]
# object detection + tracking

# %%
import cv2
from ultralytics import YOLO
import numpy as np

# Load your trained model
model = YOLO(r'E:\elevatetrsest\CamEDGE counting\bestv2.pt')

# Define the classes your model was trained on (for clarity, though model.names should have this)
CLASSES = ['box', 'box_broken', 'forklift', 'open_package', 'package', 'pallets', 'person']

def detect_and_track_warehouse_video(video_path, output_path=None, conf_threshold=0.5, tracker_config="bytetrack.yaml"):
    """
    Detect and track objects in warehouse video and count them per frame.

    Args:
        video_path: Path to input video
        output_path: Path to save output video (optional)
        conf_threshold: Confidence threshold for detections
        tracker_config: Path to the tracker configuration file (e.g., "bytetrack.yaml" or "botsort.yaml")
    """

    # Open video
    cap = cv2.VideoCapture(video_path)

    writer = None
    if output_path:
        # Get video properties
        fps = int(cap.get(cv2.CAP_PROP_FPS))
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

        # Create video writer
        fourcc = cv2.VideoWriter_fourcc(*'mp4v') # or 'XVID'
        writer = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    frame_count = 0
    total_detections_summary = {} # To store cumulative count of unique items seen based on first appearance

    # For tracking, unique IDs seen in the video
    # This simple approach counts an object ID once when it first appears.
    # For more sophisticated counting (e.g., current count on screen),
    # you'd need to manage active track IDs per frame.
    tracked_ids_ever_seen = set()

    while True:
        ret, frame = cap.read()
        if not ret:
            print("End of video or error reading frame.")
            break

        frame_count += 1

        # Run detection AND tracking
        # Use persist=True to keep track IDs consistent across frames
        # The tracker can be "bytetrack.yaml" or "botsort.yaml"
        results = model.track(frame, conf=conf_threshold, persist=True, tracker=tracker_config)

        # Process results
        current_frame_detections_count = {class_name: 0 for class_name in CLASSES} # Counts for current frame
        annotated_frame = frame.copy() # Make a copy for annotation if using results[0].plot() directly is not enough

        if results[0].boxes is not None and results[0].boxes.id is not None:
            # Get bounding boxes, confidences, class IDs, and track IDs
            boxes = results[0].boxes.xyxy.cpu().numpy() # Bounding boxes (x1, y1, x2, y2)
            confs = results[0].boxes.conf.cpu().numpy()  # Confidences
            class_ids = results[0].boxes.cls.cpu().numpy().astype(int) # Class IDs
            track_ids = results[0].boxes.id.cpu().numpy().astype(int) # Track IDs

            for i in range(len(boxes)):
                x1, y1, x2, y2 = map(int, boxes[i])
                conf = confs[i]
                class_id = class_ids[i]
                track_id = track_ids[i]

                class_name = model.names[class_id]

                # Count for current frame
                current_frame_detections_count[class_name] += 1

                # Update total unique detections summary
                if track_id not in tracked_ids_ever_seen:
                    total_detections_summary[class_name] = total_detections_summary.get(class_name, 0) + 1
                    tracked_ids_ever_seen.add(track_id)

                # Annotate the frame with bounding box, class name, confidence, and track ID
                label = f"ID:{track_id} {class_name} {conf:.2f}"
                color = (0, 255, 0) # Green for bounding box
                if class_name == "box_broken":
                    color = (0,0,255) # Red for broken box
                elif class_name == "open_package":
                    color = (0,165,255) # Orange for open package

                cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), color, 2)
                cv2.putText(annotated_frame, label, (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)

        else: # No detections or no track IDs in this frame
            # Use the original frame plot if you want to see "no detections" or default YOLO annotations
            # annotated_frame = results[0].plot()
            # For this manual drawing, if no detections, annotated_frame remains the current frame
            pass


        # Add current frame count text
        y_offset = 30
        cv2.putText(annotated_frame, f"Frame: {frame_count}",
                    (10, y_offset), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 0, 0), 2)
        y_offset += 25
        for class_name_txt, count_txt in current_frame_detections_count.items():
            if count_txt > 0: # Only display if count > 0 for cleaner UI
                cv2.putText(annotated_frame, f"{class_name_txt}: {count_txt}",
                            (10, y_offset), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
                y_offset += 25

        # Save frame if output specified
        if writer:
            writer.write(annotated_frame)

        # Display frame (optional - comment out for headless)
        cv2.imshow('Warehouse Detection and Tracking', annotated_frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

        # Print progress every 100 frames
        if frame_count % 100 == 0:
            print(f"Processed {frame_count} frames. Current frame detections: {current_frame_detections_count}")

    # Cleanup
    cap.release()
    if writer:
        writer.release()
    cv2.destroyAllWindows()

    print(f"\n🎉 Video processing complete!")
    print(f"📝 Total frames processed: {frame_count}")
    print(f"📊 Summary of unique tracked objects detected: {total_detections_summary}")

    return total_detections_summary

# Usage examples:
print("🚀 Warehouse Video Detection and Tracking System Ready!")
print("\n📝 Usage:")
print("1. Process video and display: detect_and_track_warehouse_video('your_video.mp4')")
print("2. Process and save output: detect_and_track_warehouse_video('input.mp4', 'output_tracked.mp4')")
print("3. With custom confidence: detect_and_track_warehouse_video('video.mp4', conf_threshold=0.6)")
print("4. With different tracker (e.g., BoT-SORT): detect_and_track_warehouse_video('video.mp4', tracker_config='botsort.yaml')")

# Example usage (uncomment and replace 'your_warehouse_video.mp4'):
# detections_summary = detect_and_track_warehouse_video(
# r'E:\your_path_to_video\your_warehouse_video.mp4',
# r'E:\your_path_to_video\output_with_tracking.mp4',
#     conf_threshold=0.5,
#     tracker_config="bytetrack.yaml" # or "botsort.yaml"
# )
# print(detections_summary)
# Out:
# WARNING Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\Shiva\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# 🚀 Warehouse Video Detection and Tracking System Ready!
#
# 📝 Usage:
# 1. Process video and display: detect_and_track_warehouse_video('your_video.mp4')
# 2. Process and save output: detect_and_track_warehouse_video('input.mp4', 'output_tracked.mp4')
# 3. With custom confidence: detect_and_track_warehouse_video('video.mp4', conf_threshold=0.6)
# 4. With different tracker (e.g., BoT-SORT): detect_and_track_warehouse_video('video.mp4', tracker_config='botsort.yaml')

# %%
# Example usage (uncomment and replace 'your_warehouse_video.mp4'):
detections_summary = detect_and_track_warehouse_video(
r'E:\elevatetrsest\CamEDGE counting\test\test3_warehouse.mp4',
r'E:\elevatetrsest\CamEDGE counting\tracking_output\output3.mp4',
    conf_threshold=0.5,
    tracker_config="bytetrack.yaml" # or "botsort.yaml"
)
print(detections_summary)
# Out:
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
# Collecting lap>=0.5.12
#   Downloading lap-0.5.12-cp310-cp310-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.21.6 in c:\users\shiva\appdata\roaming\python\python310\site-packages (from lap>=0.5.12) (2.1.1)
# Downloading lap-0.5.12-cp310-cp310-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 1.5/1.5 MB 5.2 MB/s eta 0:00:00
# Installing collected packages: lap
# Successfully installed lap-0.5.12
#
# requirements: AutoUpdate success  5.9s
# WARNING requirements: Restart runtime or rerun command for updates to take effect
#
#
# 0: 352x640 3 boxs, 131.0ms
# Speed: 8.1ms preprocess, 131.0ms inference, 233.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 105.6ms
# Speed: 3.1ms preprocess, 105.6ms inference, 5.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 106.0ms
# Speed: 4.2ms preprocess, 106.0ms inference, 4.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 85.1ms
# Speed: 2.5ms preprocess, 85.1ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 77.4ms
# Speed: 3.0ms preprocess, 77.4ms inference, 5.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 72.7ms
# Speed: 4.1ms preprocess, 72.7ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 72.8ms
# Speed: 2.9ms preprocess, 72.8ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 72.6ms
# Speed: 2.6ms preprocess, 72.6ms inference, 4.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 73.1ms
# Speed: 2.5ms preprocess, 73.1ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 72.6ms
# Speed: 3.0ms preprocess, 72.6ms inference, 4.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 72.7ms
# Speed: 3.4ms preprocess, 72.7ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 72.8ms
# Speed: 4.3ms preprocess, 72.8ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 72.6ms
# Speed: 2.4ms preprocess, 72.6ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 72.3ms
# Speed: 2.2ms preprocess, 72.3ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 72.4ms
# Speed: 2.9ms preprocess, 72.4ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 72.3ms
# Speed: 2.9ms preprocess, 72.3ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 72.3ms
# Speed: 2.2ms preprocess, 72.3ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 72.6ms
# Speed: 3.8ms preprocess, 72.6ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 72.2ms
# Speed: 2.3ms preprocess, 72.2ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 73.2ms
# Speed: 2.7ms preprocess, 73.2ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 72.6ms
# Speed: 3.2ms preprocess, 72.6ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 72.3ms
# Speed: 2.6ms preprocess, 72.3ms inference, 4.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 72.3ms
# Speed: 2.3ms preprocess, 72.3ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 72.4ms
# Speed: 2.5ms preprocess, 72.4ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 61.4ms
# Speed: 2.4ms preprocess, 61.4ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 59.5ms
# Speed: 2.5ms preprocess, 59.5ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 58.1ms
# Speed: 3.3ms preprocess, 58.1ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 58.3ms
# Speed: 2.3ms preprocess, 58.3ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 56.9ms
# Speed: 2.3ms preprocess, 56.9ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 56.1ms
# Speed: 2.5ms preprocess, 56.1ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 55.9ms
# Speed: 2.7ms preprocess, 55.9ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 55.4ms
# Speed: 3.3ms preprocess, 55.4ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 55.3ms
# Speed: 2.2ms preprocess, 55.3ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 1 forklift, 55.9ms
# Speed: 2.1ms preprocess, 55.9ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 1 forklift, 55.3ms
# Speed: 3.0ms preprocess, 55.3ms inference, 3.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 1 forklift, 55.5ms
# Speed: 2.8ms preprocess, 55.5ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 1 forklift, 55.5ms
# Speed: 2.8ms preprocess, 55.5ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 55.4ms
# Speed: 2.5ms preprocess, 55.4ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 55.8ms
# Speed: 2.2ms preprocess, 55.8ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 73.0ms
# Speed: 2.5ms preprocess, 73.0ms inference, 12.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 86.9ms
# Speed: 12.0ms preprocess, 86.9ms inference, 16.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 146.9ms
# Speed: 2.7ms preprocess, 146.9ms inference, 5.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 83.8ms
# Speed: 2.7ms preprocess, 83.8ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 76.2ms
# Speed: 2.5ms preprocess, 76.2ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 54.6ms
# Speed: 2.4ms preprocess, 54.6ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 51.3ms
# Speed: 2.6ms preprocess, 51.3ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 48.3ms
# Speed: 2.3ms preprocess, 48.3ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 47.9ms
# Speed: 2.8ms preprocess, 47.9ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 91.6ms
# Speed: 2.2ms preprocess, 91.6ms inference, 13.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 100.5ms
# Speed: 10.5ms preprocess, 100.5ms inference, 14.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 107.6ms
# Speed: 10.8ms preprocess, 107.6ms inference, 13.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 93.7ms
# Speed: 11.3ms preprocess, 93.7ms inference, 11.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 108.6ms
# Speed: 3.3ms preprocess, 108.6ms inference, 20.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 103.3ms
# Speed: 10.1ms preprocess, 103.3ms inference, 14.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 86.8ms
# Speed: 10.5ms preprocess, 86.8ms inference, 20.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 71.0ms
# Speed: 11.1ms preprocess, 71.0ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 61.8ms
# Speed: 3.5ms preprocess, 61.8ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 50.4ms
# Speed: 3.6ms preprocess, 50.4ms inference, 6.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 52.0ms
# Speed: 3.6ms preprocess, 52.0ms inference, 4.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 118.4ms
# Speed: 3.6ms preprocess, 118.4ms inference, 17.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 95.5ms
# Speed: 10.5ms preprocess, 95.5ms inference, 12.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 107.6ms
# Speed: 10.8ms preprocess, 107.6ms inference, 13.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 83.8ms
# Speed: 3.7ms preprocess, 83.8ms inference, 14.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 106.7ms
# Speed: 11.5ms preprocess, 106.7ms inference, 14.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 100.0ms
# Speed: 10.1ms preprocess, 100.0ms inference, 13.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 98.1ms
# Speed: 10.5ms preprocess, 98.1ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 60.1ms
# Speed: 2.0ms preprocess, 60.1ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 57.8ms
# Speed: 2.6ms preprocess, 57.8ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 52.3ms
# Speed: 2.6ms preprocess, 52.3ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 45.4ms
# Speed: 2.1ms preprocess, 45.4ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 85.2ms
# Speed: 2.1ms preprocess, 85.2ms inference, 12.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 43.2ms
# Speed: 3.1ms preprocess, 43.2ms inference, 4.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 87.7ms
# Speed: 2.4ms preprocess, 87.7ms inference, 11.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 121.6ms
# Speed: 9.9ms preprocess, 121.6ms inference, 12.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 92.5ms
# Speed: 11.8ms preprocess, 92.5ms inference, 14.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 99.0ms
# Speed: 11.4ms preprocess, 99.0ms inference, 13.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 99.9ms
# Speed: 11.6ms preprocess, 99.9ms inference, 12.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 125.0ms
# Speed: 12.6ms preprocess, 125.0ms inference, 12.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 85.7ms
# Speed: 11.1ms preprocess, 85.7ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 1 forklift, 64.7ms
# Speed: 3.0ms preprocess, 64.7ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 54.5ms
# Speed: 3.8ms preprocess, 54.5ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 54.0ms
# Speed: 2.6ms preprocess, 54.0ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 57.6ms
# Speed: 2.1ms preprocess, 57.6ms inference, 15.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 98.7ms
# Speed: 10.2ms preprocess, 98.7ms inference, 14.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 88.0ms
# Speed: 10.6ms preprocess, 88.0ms inference, 11.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 84.3ms
# Speed: 11.2ms preprocess, 84.3ms inference, 11.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 46.6ms
# Speed: 4.2ms preprocess, 46.6ms inference, 5.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 45.4ms
# Speed: 3.9ms preprocess, 45.4ms inference, 5.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 55.5ms
# Speed: 3.7ms preprocess, 55.5ms inference, 13.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 101.7ms
# Speed: 10.1ms preprocess, 101.7ms inference, 12.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 96.2ms
# Speed: 10.9ms preprocess, 96.2ms inference, 11.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 99.3ms
# Speed: 11.2ms preprocess, 99.3ms inference, 13.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 89.3ms
# Speed: 2.4ms preprocess, 89.3ms inference, 14.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 94.1ms
# Speed: 10.3ms preprocess, 94.1ms inference, 13.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 108.3ms
# Speed: 11.7ms preprocess, 108.3ms inference, 12.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 126.0ms
# Speed: 10.2ms preprocess, 126.0ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 61.0ms
# Speed: 3.1ms preprocess, 61.0ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 57.3ms
# Speed: 2.0ms preprocess, 57.3ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 1 forklift, 49.8ms
# Speed: 2.1ms preprocess, 49.8ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 1 forklift, 49.5ms
# Speed: 2.1ms preprocess, 49.5ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
# Processed 100 frames. Current frame detections: {'box': 2, 'box_broken': 0, 'forklift': 1, 'open_package': 0, 'package': 0, 'pallets': 0, 'person': 0}
#
# 0: 352x640 2 boxs, 99.4ms
# Speed: 2.1ms preprocess, 99.4ms inference, 15.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 87.4ms
# Speed: 9.9ms preprocess, 87.4ms inference, 12.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 95.3ms
# Speed: 10.1ms preprocess, 95.3ms inference, 13.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 82.5ms
# Speed: 10.1ms preprocess, 82.5ms inference, 13.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 86.0ms
# Speed: 10.0ms preprocess, 86.0ms inference, 12.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 76.1ms
# Speed: 2.2ms preprocess, 76.1ms inference, 12.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 111.0ms
# Speed: 10.1ms preprocess, 111.0ms inference, 13.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 92.5ms
# Speed: 10.6ms preprocess, 92.5ms inference, 12.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 87.6ms
# Speed: 9.8ms preprocess, 87.6ms inference, 12.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 57.0ms
# Speed: 2.6ms preprocess, 57.0ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 57.7ms
# Speed: 3.4ms preprocess, 57.7ms inference, 4.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 1 forklift, 86.0ms
# Speed: 2.5ms preprocess, 86.0ms inference, 13.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 99.9ms
# Speed: 10.5ms preprocess, 99.9ms inference, 12.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 87.8ms
# Speed: 11.0ms preprocess, 87.8ms inference, 12.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 114.1ms
# Speed: 10.2ms preprocess, 114.1ms inference, 4.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 94.9ms
# Speed: 2.4ms preprocess, 94.9ms inference, 11.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 101.6ms
# Speed: 11.6ms preprocess, 101.6ms inference, 14.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 100.4ms
# Speed: 10.6ms preprocess, 100.4ms inference, 13.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 94.1ms
# Speed: 9.9ms preprocess, 94.1ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 57.4ms
# Speed: 2.9ms preprocess, 57.4ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 57.6ms
# Speed: 2.1ms preprocess, 57.6ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 50.0ms
# Speed: 3.0ms preprocess, 50.0ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 47.5ms
# Speed: 2.7ms preprocess, 47.5ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 47.1ms
# Speed: 2.2ms preprocess, 47.1ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 81.5ms
# Speed: 2.3ms preprocess, 81.5ms inference, 14.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 93.5ms
# Speed: 10.1ms preprocess, 93.5ms inference, 13.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 106.0ms
# Speed: 11.0ms preprocess, 106.0ms inference, 14.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 102.0ms
# Speed: 3.2ms preprocess, 102.0ms inference, 13.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 91.4ms
# Speed: 9.7ms preprocess, 91.4ms inference, 11.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 81.4ms
# Speed: 9.7ms preprocess, 81.4ms inference, 13.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 1 forklift, 95.6ms
# Speed: 10.2ms preprocess, 95.6ms inference, 12.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 88.9ms
# Speed: 10.3ms preprocess, 88.9ms inference, 13.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 91.5ms
# Speed: 10.1ms preprocess, 91.5ms inference, 12.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 95.8ms
# Speed: 11.5ms preprocess, 95.8ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 59.9ms
# Speed: 3.6ms preprocess, 59.9ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 56.7ms
# Speed: 2.2ms preprocess, 56.7ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 52.6ms
# Speed: 2.0ms preprocess, 52.6ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 52.1ms
# Speed: 2.2ms preprocess, 52.1ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 68.6ms
# Speed: 3.2ms preprocess, 68.6ms inference, 13.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 97.9ms
# Speed: 10.4ms preprocess, 97.9ms inference, 13.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 86.0ms
# Speed: 9.9ms preprocess, 86.0ms inference, 12.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 96.7ms
# Speed: 10.0ms preprocess, 96.7ms inference, 12.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 94.4ms
# Speed: 10.1ms preprocess, 94.4ms inference, 11.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 85.1ms
# Speed: 9.8ms preprocess, 85.1ms inference, 12.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 99.0ms
# Speed: 2.1ms preprocess, 99.0ms inference, 12.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 101.2ms
# Speed: 10.5ms preprocess, 101.2ms inference, 15.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 114.1ms
# Speed: 18.7ms preprocess, 114.1ms inference, 14.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 65.4ms
# Speed: 11.4ms preprocess, 65.4ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 61.1ms
# Speed: 3.3ms preprocess, 61.1ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 58.2ms
# Speed: 2.2ms preprocess, 58.2ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 50.8ms
# Speed: 3.1ms preprocess, 50.8ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 105.0ms
# Speed: 2.3ms preprocess, 105.0ms inference, 12.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 94.4ms
# Speed: 11.1ms preprocess, 94.4ms inference, 7.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 103.7ms
# Speed: 9.7ms preprocess, 103.7ms inference, 7.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 102.5ms
# Speed: 10.5ms preprocess, 102.5ms inference, 5.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 44.9ms
# Speed: 2.3ms preprocess, 44.9ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 45.5ms
# Speed: 3.7ms preprocess, 45.5ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 45.9ms
# Speed: 2.3ms preprocess, 45.9ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 81.5ms
# Speed: 3.6ms preprocess, 81.5ms inference, 13.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 87.9ms
# Speed: 10.4ms preprocess, 87.9ms inference, 12.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 90.1ms
# Speed: 12.0ms preprocess, 90.1ms inference, 12.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 90.2ms
# Speed: 9.7ms preprocess, 90.2ms inference, 13.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 80.1ms
# Speed: 2.3ms preprocess, 80.1ms inference, 11.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 90.4ms
# Speed: 10.2ms preprocess, 90.4ms inference, 15.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 88.6ms
# Speed: 9.9ms preprocess, 88.6ms inference, 11.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 94.4ms
# Speed: 9.8ms preprocess, 94.4ms inference, 6.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 59.8ms
# Speed: 2.4ms preprocess, 59.8ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 53.7ms
# Speed: 4.4ms preprocess, 53.7ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 53.6ms
# Speed: 4.0ms preprocess, 53.6ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 93.0ms
# Speed: 2.5ms preprocess, 93.0ms inference, 12.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 90.5ms
# Speed: 11.4ms preprocess, 90.5ms inference, 12.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 91.7ms
# Speed: 9.9ms preprocess, 91.7ms inference, 12.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 91.4ms
# Speed: 10.6ms preprocess, 91.4ms inference, 12.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 71.0ms
# Speed: 2.8ms preprocess, 71.0ms inference, 5.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 77.7ms
# Speed: 9.9ms preprocess, 77.7ms inference, 5.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 98.0ms
# Speed: 10.6ms preprocess, 98.0ms inference, 6.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 115.7ms
# Speed: 11.1ms preprocess, 115.7ms inference, 12.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 61.6ms
# Speed: 5.1ms preprocess, 61.6ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 62.2ms
# Speed: 2.3ms preprocess, 62.2ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 48.9ms
# Speed: 2.9ms preprocess, 48.9ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 71.9ms
# Speed: 2.2ms preprocess, 71.9ms inference, 5.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 91.3ms
# Speed: 10.2ms preprocess, 91.3ms inference, 5.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 107.3ms
# Speed: 9.9ms preprocess, 107.3ms inference, 12.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 110.4ms
# Speed: 15.4ms preprocess, 110.4ms inference, 12.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 114.2ms
# Speed: 2.7ms preprocess, 114.2ms inference, 17.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 93.5ms
# Speed: 10.6ms preprocess, 93.5ms inference, 11.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 96.6ms
# Speed: 10.1ms preprocess, 96.6ms inference, 12.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 76.4ms
# Speed: 10.5ms preprocess, 76.4ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 60.7ms
# Speed: 2.5ms preprocess, 60.7ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 61.1ms
# Speed: 3.8ms preprocess, 61.1ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 46.2ms
# Speed: 2.3ms preprocess, 46.2ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 87.7ms
# Speed: 3.5ms preprocess, 87.7ms inference, 5.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 118.1ms
# Speed: 10.3ms preprocess, 118.1ms inference, 6.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 163.8ms
# Speed: 10.6ms preprocess, 163.8ms inference, 12.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 54.4ms
# Speed: 10.5ms preprocess, 54.4ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 46.7ms
# Speed: 2.7ms preprocess, 46.7ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 45.8ms
# Speed: 2.9ms preprocess, 45.8ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 45.7ms
# Speed: 3.7ms preprocess, 45.7ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 79.7ms
# Speed: 3.4ms preprocess, 79.7ms inference, 15.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 94.6ms
# Speed: 10.0ms preprocess, 94.6ms inference, 12.2ms postprocess per image at shape (1, 3, 352, 640)
# Processed 200 frames. Current frame detections: {'box': 1, 'box_broken': 0, 'forklift': 0, 'open_package': 0, 'package': 0, 'pallets': 0, 'person': 0}
#
# 0: 352x640 1 box, 104.2ms
# Speed: 10.3ms preprocess, 104.2ms inference, 21.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 88.5ms
# Speed: 11.4ms preprocess, 88.5ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 80.8ms
# Speed: 3.7ms preprocess, 80.8ms inference, 13.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 127.6ms
# Speed: 10.9ms preprocess, 127.6ms inference, 5.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 122.3ms
# Speed: 11.1ms preprocess, 122.3ms inference, 5.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 89.2ms
# Speed: 11.2ms preprocess, 89.2ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 61.1ms
# Speed: 2.2ms preprocess, 61.1ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 54.6ms
# Speed: 2.8ms preprocess, 54.6ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 47.8ms
# Speed: 3.4ms preprocess, 47.8ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 57.1ms
# Speed: 2.7ms preprocess, 57.1ms inference, 8.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 91.8ms
# Speed: 10.1ms preprocess, 91.8ms inference, 6.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 100.9ms
# Speed: 10.6ms preprocess, 100.9ms inference, 5.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 106.8ms
# Speed: 9.9ms preprocess, 106.8ms inference, 5.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 90.6ms
# Speed: 9.7ms preprocess, 90.6ms inference, 5.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 141.0ms
# Speed: 11.6ms preprocess, 141.0ms inference, 13.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 107.5ms
# Speed: 10.7ms preprocess, 107.5ms inference, 13.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 62.6ms
# Speed: 2.3ms preprocess, 62.6ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 60.4ms
# Speed: 3.5ms preprocess, 60.4ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 59.1ms
# Speed: 2.2ms preprocess, 59.1ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 51.0ms
# Speed: 3.6ms preprocess, 51.0ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 50.0ms
# Speed: 2.5ms preprocess, 50.0ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 57.2ms
# Speed: 2.2ms preprocess, 57.2ms inference, 10.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 92.3ms
# Speed: 10.3ms preprocess, 92.3ms inference, 5.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 134.9ms
# Speed: 11.7ms preprocess, 134.9ms inference, 5.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 95.6ms
# Speed: 10.4ms preprocess, 95.6ms inference, 5.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 95.3ms
# Speed: 10.6ms preprocess, 95.3ms inference, 5.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 86.7ms
# Speed: 10.8ms preprocess, 86.7ms inference, 5.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 89.1ms
# Speed: 10.8ms preprocess, 89.1ms inference, 14.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 95.9ms
# Speed: 10.1ms preprocess, 95.9ms inference, 13.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 62.3ms
# Speed: 10.4ms preprocess, 62.3ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 61.6ms
# Speed: 3.8ms preprocess, 61.6ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 61.6ms
# Speed: 2.9ms preprocess, 61.6ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 47.1ms
# Speed: 2.4ms preprocess, 47.1ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 92.4ms
# Speed: 2.5ms preprocess, 92.4ms inference, 16.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 94.6ms
# Speed: 9.6ms preprocess, 94.6ms inference, 22.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 104.2ms
# Speed: 11.3ms preprocess, 104.2ms inference, 12.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 129.2ms
# Speed: 4.2ms preprocess, 129.2ms inference, 17.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 87.7ms
# Speed: 12.5ms preprocess, 87.7ms inference, 13.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 76.4ms
# Speed: 4.3ms preprocess, 76.4ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 67.9ms
# Speed: 3.6ms preprocess, 67.9ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 64.2ms
# Speed: 2.6ms preprocess, 64.2ms inference, 5.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 85.7ms
# Speed: 2.6ms preprocess, 85.7ms inference, 13.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 125.2ms
# Speed: 12.6ms preprocess, 125.2ms inference, 12.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 99.1ms
# Speed: 11.1ms preprocess, 99.1ms inference, 12.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 51.5ms
# Speed: 4.0ms preprocess, 51.5ms inference, 6.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 51.5ms
# Speed: 3.5ms preprocess, 51.5ms inference, 3.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 51.6ms
# Speed: 3.3ms preprocess, 51.6ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 51.3ms
# Speed: 3.1ms preprocess, 51.3ms inference, 3.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 46.6ms
# Speed: 2.3ms preprocess, 46.6ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 47.6ms
# Speed: 3.8ms preprocess, 47.6ms inference, 3.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 46.5ms
# Speed: 3.3ms preprocess, 46.5ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 46.5ms
# Speed: 2.3ms preprocess, 46.5ms inference, 4.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 102.4ms
# Speed: 2.1ms preprocess, 102.4ms inference, 12.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 163.9ms
# Speed: 11.5ms preprocess, 163.9ms inference, 13.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 107.3ms
# Speed: 13.4ms preprocess, 107.3ms inference, 12.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 53.0ms
# Speed: 2.8ms preprocess, 53.0ms inference, 5.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 45.3ms
# Speed: 3.3ms preprocess, 45.3ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 55.8ms
# Speed: 2.5ms preprocess, 55.8ms inference, 19.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 231.5ms
# Speed: 10.5ms preprocess, 231.5ms inference, 26.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 201.5ms
# Speed: 15.4ms preprocess, 201.5ms inference, 21.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 197.2ms
# Speed: 5.7ms preprocess, 197.2ms inference, 25.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 223.5ms
# Speed: 16.8ms preprocess, 223.5ms inference, 25.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 65.2ms
# Speed: 6.3ms preprocess, 65.2ms inference, 7.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 66.2ms
# Speed: 7.3ms preprocess, 66.2ms inference, 8.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 71.8ms
# Speed: 4.7ms preprocess, 71.8ms inference, 8.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 63.3ms
# Speed: 5.9ms preprocess, 63.3ms inference, 7.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 68.7ms
# Speed: 5.9ms preprocess, 68.7ms inference, 8.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 57.1ms
# Speed: 5.4ms preprocess, 57.1ms inference, 8.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 78.2ms
# Speed: 6.4ms preprocess, 78.2ms inference, 7.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 55.0ms
# Speed: 6.1ms preprocess, 55.0ms inference, 7.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 58.7ms
# Speed: 6.3ms preprocess, 58.7ms inference, 7.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 56.6ms
# Speed: 5.9ms preprocess, 56.6ms inference, 7.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 108.5ms
# Speed: 5.9ms preprocess, 108.5ms inference, 23.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 203.1ms
# Speed: 15.6ms preprocess, 203.1ms inference, 27.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 219.5ms
# Speed: 15.0ms preprocess, 219.5ms inference, 8.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 63.0ms
# Speed: 5.5ms preprocess, 63.0ms inference, 7.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 60.7ms
# Speed: 5.6ms preprocess, 60.7ms inference, 7.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 56.9ms
# Speed: 5.4ms preprocess, 56.9ms inference, 6.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 50.5ms
# Speed: 6.0ms preprocess, 50.5ms inference, 7.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 57.4ms
# Speed: 6.0ms preprocess, 57.4ms inference, 8.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 58.7ms
# Speed: 5.6ms preprocess, 58.7ms inference, 10.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 70.2ms
# Speed: 9.0ms preprocess, 70.2ms inference, 7.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 59.2ms
# Speed: 5.4ms preprocess, 59.2ms inference, 7.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 59.7ms
# Speed: 5.7ms preprocess, 59.7ms inference, 7.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 49.9ms
# Speed: 5.4ms preprocess, 49.9ms inference, 7.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 194.1ms
# Speed: 5.9ms preprocess, 194.1ms inference, 23.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 198.7ms
# Speed: 15.8ms preprocess, 198.7ms inference, 22.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 123.4ms
# Speed: 15.3ms preprocess, 123.4ms inference, 7.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 55.3ms
# Speed: 5.4ms preprocess, 55.3ms inference, 7.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 58.2ms
# Speed: 5.6ms preprocess, 58.2ms inference, 7.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 51.3ms
# Speed: 5.4ms preprocess, 51.3ms inference, 7.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 48.6ms
# Speed: 5.2ms preprocess, 48.6ms inference, 7.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 55.2ms
# Speed: 5.8ms preprocess, 55.2ms inference, 6.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 140.1ms
# Speed: 6.6ms preprocess, 140.1ms inference, 25.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 206.9ms
# Speed: 15.2ms preprocess, 206.9ms inference, 26.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 162.6ms
# Speed: 15.3ms preprocess, 162.6ms inference, 22.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 223.7ms
# Speed: 15.6ms preprocess, 223.7ms inference, 23.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 125.2ms
# Speed: 15.0ms preprocess, 125.2ms inference, 7.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 75.9ms
# Speed: 6.1ms preprocess, 75.9ms inference, 7.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 71.4ms
# Speed: 5.3ms preprocess, 71.4ms inference, 7.4ms postprocess per image at shape (1, 3, 352, 640)
# Processed 300 frames. Current frame detections: {'box': 0, 'box_broken': 0, 'forklift': 0, 'open_package': 0, 'package': 0, 'pallets': 0, 'person': 1}
#
# 0: 352x640 1 person, 59.3ms
# Speed: 5.6ms preprocess, 59.3ms inference, 7.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 59.1ms
# Speed: 5.7ms preprocess, 59.1ms inference, 8.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 59.3ms
# Speed: 5.6ms preprocess, 59.3ms inference, 7.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 59.3ms
# Speed: 5.6ms preprocess, 59.3ms inference, 7.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 59.6ms
# Speed: 5.7ms preprocess, 59.6ms inference, 7.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 55.1ms
# Speed: 6.3ms preprocess, 55.1ms inference, 6.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 54.5ms
# Speed: 5.6ms preprocess, 54.5ms inference, 7.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 60.8ms
# Speed: 5.6ms preprocess, 60.8ms inference, 7.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 58.7ms
# Speed: 6.8ms preprocess, 58.7ms inference, 7.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 53.5ms
# Speed: 5.5ms preprocess, 53.5ms inference, 8.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 63.0ms
# Speed: 5.2ms preprocess, 63.0ms inference, 7.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 55.2ms
# Speed: 5.7ms preprocess, 55.2ms inference, 7.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 54.2ms
# Speed: 5.7ms preprocess, 54.2ms inference, 6.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 56.8ms
# Speed: 5.6ms preprocess, 56.8ms inference, 7.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 61.3ms
# Speed: 5.8ms preprocess, 61.3ms inference, 7.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 186.3ms
# Speed: 5.2ms preprocess, 186.3ms inference, 26.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 202.9ms
# Speed: 16.9ms preprocess, 202.9ms inference, 23.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 136.6ms
# Speed: 14.7ms preprocess, 136.6ms inference, 7.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 60.7ms
# Speed: 5.6ms preprocess, 60.7ms inference, 8.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 127.3ms
# Speed: 6.0ms preprocess, 127.3ms inference, 24.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 212.3ms
# Speed: 16.0ms preprocess, 212.3ms inference, 26.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 195.2ms
# Speed: 15.7ms preprocess, 195.2ms inference, 8.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 67.9ms
# Speed: 5.7ms preprocess, 67.9ms inference, 8.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 67.2ms
# Speed: 5.5ms preprocess, 67.2ms inference, 8.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 65.5ms
# Speed: 5.5ms preprocess, 65.5ms inference, 9.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 65.1ms
# Speed: 5.8ms preprocess, 65.1ms inference, 7.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 65.7ms
# Speed: 5.6ms preprocess, 65.7ms inference, 7.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 63.6ms
# Speed: 5.6ms preprocess, 63.6ms inference, 12.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 61.8ms
# Speed: 5.8ms preprocess, 61.8ms inference, 7.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 58.9ms
# Speed: 5.4ms preprocess, 58.9ms inference, 7.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 57.5ms
# Speed: 5.4ms preprocess, 57.5ms inference, 7.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 57.6ms
# Speed: 5.8ms preprocess, 57.6ms inference, 7.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 56.9ms
# Speed: 5.1ms preprocess, 56.9ms inference, 7.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 49.8ms
# Speed: 5.6ms preprocess, 49.8ms inference, 6.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 57.8ms
# Speed: 5.1ms preprocess, 57.8ms inference, 8.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 47.8ms
# Speed: 5.3ms preprocess, 47.8ms inference, 7.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 48.0ms
# Speed: 5.2ms preprocess, 48.0ms inference, 6.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 48.7ms
# Speed: 5.4ms preprocess, 48.7ms inference, 7.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 59.9ms
# Speed: 4.1ms preprocess, 59.9ms inference, 7.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 59.9ms
# Speed: 5.3ms preprocess, 59.9ms inference, 7.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 56.1ms
# Speed: 5.9ms preprocess, 56.1ms inference, 7.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 54.9ms
# Speed: 5.5ms preprocess, 54.9ms inference, 7.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 53.9ms
# Speed: 5.0ms preprocess, 53.9ms inference, 7.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 49.2ms
# Speed: 4.8ms preprocess, 49.2ms inference, 7.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 53.8ms
# Speed: 5.2ms preprocess, 53.8ms inference, 7.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 64.2ms
# Speed: 5.8ms preprocess, 64.2ms inference, 7.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 202.9ms
# Speed: 7.4ms preprocess, 202.9ms inference, 24.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 216.3ms
# Speed: 16.1ms preprocess, 216.3ms inference, 34.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 213.7ms
# Speed: 16.7ms preprocess, 213.7ms inference, 27.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 285.3ms
# Speed: 15.6ms preprocess, 285.3ms inference, 15.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 236.2ms
# Speed: 6.3ms preprocess, 236.2ms inference, 11.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 220.4ms
# Speed: 18.5ms preprocess, 220.4ms inference, 11.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 112.1ms
# Speed: 16.9ms preprocess, 112.1ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 82.4ms
# Speed: 5.4ms preprocess, 82.4ms inference, 9.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 forklift, 1 person, 80.0ms
# Speed: 5.7ms preprocess, 80.0ms inference, 7.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 79.7ms
# Speed: 5.9ms preprocess, 79.7ms inference, 8.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 80.7ms
# Speed: 6.3ms preprocess, 80.7ms inference, 8.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 79.1ms
# Speed: 5.9ms preprocess, 79.1ms inference, 7.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 73.4ms
# Speed: 5.5ms preprocess, 73.4ms inference, 8.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 68.0ms
# Speed: 5.6ms preprocess, 68.0ms inference, 7.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 60.3ms
# Speed: 6.2ms preprocess, 60.3ms inference, 7.1ms postprocess per image at shape (1, 3, 352, 640)
#
# ...
#
# 0: 352x640 1 box, 1 forklift, 205.2ms
# Speed: 15.6ms preprocess, 205.2ms inference, 24.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 1 forklift, 135.4ms
# Speed: 14.9ms preprocess, 135.4ms inference, 28.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 1 forklift, 216.8ms
# Speed: 18.2ms preprocess, 216.8ms inference, 22.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 1 forklift, 209.2ms
# Speed: 5.3ms preprocess, 209.2ms inference, 26.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 1 forklift, 220.8ms
# Speed: 16.1ms preprocess, 220.8ms inference, 24.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 203.3ms
# Speed: 15.1ms preprocess, 203.3ms inference, 25.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 218.9ms
# Speed: 15.1ms preprocess, 218.9ms inference, 25.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 104.9ms
# Speed: 16.8ms preprocess, 104.9ms inference, 8.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 69.3ms
# Speed: 4.9ms preprocess, 69.3ms inference, 8.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 61.7ms
# Speed: 5.7ms preprocess, 61.7ms inference, 8.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 62.3ms
# Speed: 4.9ms preprocess, 62.3ms inference, 6.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 232.9ms
# Speed: 4.7ms preprocess, 232.9ms inference, 24.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 203.1ms
# Speed: 16.9ms preprocess, 203.1ms inference, 22.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 193.9ms
# Speed: 15.5ms preprocess, 193.9ms inference, 24.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 205.9ms
# Speed: 17.3ms preprocess, 205.9ms inference, 22.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 158.7ms
# Speed: 15.8ms preprocess, 158.7ms inference, 7.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 65.9ms
# Speed: 5.4ms preprocess, 65.9ms inference, 7.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 165.2ms
# Speed: 4.3ms preprocess, 165.2ms inference, 23.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 220.3ms
# Speed: 16.7ms preprocess, 220.3ms inference, 27.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 75.9ms
# Speed: 16.0ms preprocess, 75.9ms inference, 7.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 61.9ms
# Speed: 6.0ms preprocess, 61.9ms inference, 8.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 221.5ms
# Speed: 5.1ms preprocess, 221.5ms inference, 22.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 211.1ms
# Speed: 15.4ms preprocess, 211.1ms inference, 26.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 231.7ms
# Speed: 15.8ms preprocess, 231.7ms inference, 58.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 228.0ms
# Speed: 16.4ms preprocess, 228.0ms inference, 28.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 box, 105.2ms
# Speed: 5.9ms preprocess, 105.2ms inference, 44.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 202.4ms
# Speed: 16.5ms preprocess, 202.4ms inference, 25.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 177.2ms
# Speed: 16.0ms preprocess, 177.2ms inference, 7.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 80.7ms
# Speed: 5.0ms preprocess, 80.7ms inference, 6.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 72.7ms
# Speed: 5.4ms preprocess, 72.7ms inference, 8.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 56.0ms
# Speed: 5.3ms preprocess, 56.0ms inference, 7.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 56.2ms
# Speed: 5.9ms preprocess, 56.2ms inference, 7.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 63.9ms
# Speed: 6.7ms preprocess, 63.9ms inference, 7.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 68.3ms
# Speed: 9.5ms preprocess, 68.3ms inference, 30.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 200.1ms
# Speed: 21.0ms preprocess, 200.1ms inference, 27.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 204.6ms
# Speed: 17.0ms preprocess, 204.6ms inference, 26.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 65.7ms
# Speed: 5.9ms preprocess, 65.7ms inference, 8.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 119.7ms
# Speed: 5.9ms preprocess, 119.7ms inference, 27.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 206.4ms
# Speed: 16.0ms preprocess, 206.4ms inference, 24.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 65.3ms
# Speed: 6.0ms preprocess, 65.3ms inference, 7.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 63.5ms
# Speed: 5.9ms preprocess, 63.5ms inference, 8.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 63.1ms
# Speed: 6.2ms preprocess, 63.1ms inference, 9.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 75.3ms
# Speed: 5.5ms preprocess, 75.3ms inference, 8.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 236.1ms
# Speed: 4.5ms preprocess, 236.1ms inference, 22.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 223.6ms
# Speed: 16.3ms preprocess, 223.6ms inference, 22.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 257.6ms
# Speed: 14.6ms preprocess, 257.6ms inference, 25.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 55.4ms
# Speed: 4.2ms preprocess, 55.4ms inference, 7.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 69.3ms
# Speed: 5.7ms preprocess, 69.3ms inference, 9.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 202.8ms
# Speed: 5.9ms preprocess, 202.8ms inference, 24.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 229.8ms
# Speed: 18.1ms preprocess, 229.8ms inference, 26.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 187.1ms
# Speed: 20.2ms preprocess, 187.1ms inference, 23.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 213.2ms
# Speed: 16.6ms preprocess, 213.2ms inference, 7.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 72.0ms
# Speed: 5.1ms preprocess, 72.0ms inference, 7.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 71.7ms
# Speed: 5.7ms preprocess, 71.7ms inference, 6.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 67.7ms
# Speed: 6.6ms preprocess, 67.7ms inference, 7.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 64.0ms
# Speed: 5.7ms preprocess, 64.0ms inference, 7.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 70.7ms
# Speed: 5.9ms preprocess, 70.7ms inference, 9.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 235.7ms
# Speed: 6.2ms preprocess, 235.7ms inference, 26.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 254.8ms
# Speed: 17.6ms preprocess, 254.8ms inference, 32.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 266.5ms
# Speed: 6.0ms preprocess, 266.5ms inference, 57.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 290.0ms
# Speed: 16.4ms preprocess, 290.0ms inference, 32.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 87.3ms
# Speed: 6.0ms preprocess, 87.3ms inference, 8.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 76.5ms
# Speed: 6.1ms preprocess, 76.5ms inference, 8.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 64.5ms
# Speed: 5.1ms preprocess, 64.5ms inference, 8.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 56.6ms
# Speed: 5.0ms preprocess, 56.6ms inference, 7.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 273.1ms
# Speed: 8.7ms preprocess, 273.1ms inference, 38.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 178.8ms
# Speed: 5.0ms preprocess, 178.8ms inference, 25.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 209.1ms
# Speed: 16.0ms preprocess, 209.1ms inference, 34.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 197.7ms
# Speed: 19.5ms preprocess, 197.7ms inference, 23.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 215.7ms
# Speed: 15.7ms preprocess, 215.7ms inference, 28.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 119.0ms
# Speed: 15.6ms preprocess, 119.0ms inference, 7.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 77.8ms
# Speed: 6.7ms preprocess, 77.8ms inference, 7.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 77.0ms
# Speed: 4.7ms preprocess, 77.0ms inference, 8.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 67.1ms
# Speed: 4.8ms preprocess, 67.1ms inference, 7.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 63.4ms
# Speed: 5.5ms preprocess, 63.4ms inference, 7.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 58.1ms
# Speed: 6.3ms preprocess, 58.1ms inference, 8.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 51.2ms
# Speed: 7.2ms preprocess, 51.2ms inference, 7.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 63.4ms
# Speed: 5.4ms preprocess, 63.4ms inference, 9.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 55.5ms
# Speed: 6.4ms preprocess, 55.5ms inference, 7.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 184.4ms
# Speed: 5.5ms preprocess, 184.4ms inference, 26.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 235.0ms
# Speed: 17.6ms preprocess, 235.0ms inference, 22.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 232.8ms
# Speed: 16.7ms preprocess, 232.8ms inference, 29.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 214.0ms
# Speed: 17.3ms preprocess, 214.0ms inference, 26.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 78.7ms
# Speed: 7.5ms preprocess, 78.7ms inference, 8.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 75.0ms
# Speed: 6.2ms preprocess, 75.0ms inference, 7.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 70.3ms
# Speed: 5.6ms preprocess, 70.3ms inference, 7.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 66.3ms
# Speed: 4.8ms preprocess, 66.3ms inference, 8.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 186.0ms
# Speed: 5.2ms preprocess, 186.0ms inference, 25.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 4 boxs, 232.4ms
# Speed: 16.6ms preprocess, 232.4ms inference, 25.5ms postprocess per image at shape (1, 3, 352, 640)
# Processed 600 frames. Current frame detections: {'box': 4, 'box_broken': 0, 'forklift': 0, 'open_package': 0, 'package': 0, 'pallets': 0, 'person': 0}
#
# 0: 352x640 3 boxs, 114.6ms
# Speed: 16.5ms preprocess, 114.6ms inference, 25.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 206.4ms
# Speed: 15.4ms preprocess, 206.4ms inference, 22.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 161.7ms
# Speed: 15.6ms preprocess, 161.7ms inference, 7.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 77.8ms
# Speed: 5.4ms preprocess, 77.8ms inference, 7.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 79.4ms
# Speed: 5.3ms preprocess, 79.4ms inference, 7.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 74.1ms
# Speed: 5.5ms preprocess, 74.1ms inference, 9.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 67.5ms
# Speed: 5.1ms preprocess, 67.5ms inference, 7.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 56.7ms
# Speed: 4.8ms preprocess, 56.7ms inference, 8.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 48.1ms
# Speed: 5.0ms preprocess, 48.1ms inference, 6.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 boxs, 51.5ms
# Speed: 5.2ms preprocess, 51.5ms inference, 7.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 57.2ms
# Speed: 5.5ms preprocess, 57.2ms inference, 7.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 197.4ms
# Speed: 5.5ms preprocess, 197.4ms inference, 22.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 209.4ms
# Speed: 15.4ms preprocess, 209.4ms inference, 21.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 129.2ms
# Speed: 15.4ms preprocess, 129.2ms inference, 25.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 boxs, 242.5ms
# Speed: 17.2ms preprocess, 242.5ms inference, 25.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 202.9ms
# Speed: 16.6ms preprocess, 202.9ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 182.7ms
# Speed: 5.5ms preprocess, 182.7ms inference, 9.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 202.0ms
# Speed: 15.8ms preprocess, 202.0ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 76.4ms
# Speed: 5.6ms preprocess, 76.4ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 68.2ms
# Speed: 5.2ms preprocess, 68.2ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 68.9ms
# Speed: 5.4ms preprocess, 68.9ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 69.4ms
# Speed: 5.3ms preprocess, 69.4ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 55.6ms
# Speed: 5.8ms preprocess, 55.6ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 54.6ms
# Speed: 5.3ms preprocess, 54.6ms inference, 3.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 54.9ms
# Speed: 5.1ms preprocess, 54.9ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 54.7ms
# Speed: 5.2ms preprocess, 54.7ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 55.9ms
# Speed: 5.4ms preprocess, 55.9ms inference, 4.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 57.1ms
# Speed: 5.7ms preprocess, 57.1ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 54.6ms
# Speed: 4.6ms preprocess, 54.6ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 58.4ms
# Speed: 5.1ms preprocess, 58.4ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 54.4ms
# Speed: 5.6ms preprocess, 54.4ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 54.1ms
# Speed: 5.5ms preprocess, 54.1ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 57.2ms
# Speed: 5.4ms preprocess, 57.2ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
# End of video or error reading frame.
#
# 🎉 Video processing complete!
# 📝 Total frames processed: 633
# 📊 Summary of unique tracked objects detected: {'box': 16, 'forklift': 6, 'person': 1}
# {'box': 16, 'forklift': 6, 'person': 1}

# %% [markdown]
# object tracking (only box)

# %%
import cv2
from ultralytics import YOLO
import numpy as np

# Load your trained model
model = YOLO(r'E:\elevatetrsest\CamEDGE counting\bestv2.pt') # Use your model path

# Define the classes your model was trained on
CLASSES = ['box', 'box_broken', 'forklift', 'open_package', 'package', 'pallets', 'person']
CLASS_TO_TRACK_EXCLUSIVELY = 'box'

def detect_and_selectively_track_video(video_path, output_path=None, conf_threshold=0.5, tracker_config="bytetrack.yaml"):
    """
    Detect all objects, but only display track IDs for the 'box' class.
    Counts all objects per frame and unique 'box' instances.

    Args:
        video_path: Path to input video
        output_path: Path to save output video (optional)
        conf_threshold: Confidence threshold for detections
        tracker_config: Path to the tracker configuration file
    """
    cap = cv2.VideoCapture(video_path)
    writer = None

    if output_path:
        fps = int(cap.get(cv2.CAP_PROP_FPS))
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        fourcc = cv2.VideoWriter_fourcc(*'mp4v') # or 'XVID'
        writer = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    frame_count = 0
    
    # For counting unique 'box' objects based on their track ID
    total_unique_tracked_boxes = 0
    seen_box_track_ids = set()

    # For counting all object types per frame
    current_frame_object_counts = {class_name: 0 for class_name in CLASSES}
    # For overall summary of any object detected at least once (can be based on track ID if available)
    # This can be adjusted if you only want summary for boxes.
    # For now, it will count any object with a track ID once.
    overall_objects_summary = {class_name: 0 for class_name in CLASSES}
    overall_seen_track_ids = set()


    while True:
        ret, frame = cap.read()
        if not ret:
            print("End of video or error reading frame.")
            break
        frame_count += 1
        annotated_frame = frame.copy()

        # Run detection AND tracking
        # persist=True is important for consistent track IDs
        results = model.track(frame, conf=conf_threshold, persist=True, tracker=tracker_config, verbose=False)

        # Reset per-frame counts
        current_frame_object_counts = {class_name: 0 for class_name in CLASSES}

        if results[0].boxes is not None: # Check if there are any detections
            boxes_data = results[0].boxes.xyxy.cpu().numpy()
            confs_data = results[0].boxes.conf.cpu().numpy()
            class_ids_data = results[0].boxes.cls.cpu().numpy().astype(int)
            
            # track_ids might be None if no objects are being tracked yet or tracker failed
            track_ids_data = None
            if results[0].boxes.id is not None:
                track_ids_data = results[0].boxes.id.cpu().numpy().astype(int)

            for i in range(len(boxes_data)):
                x1, y1, x2, y2 = map(int, boxes_data[i])
                conf = confs_data[i]
                class_id = class_ids_data[i]
                class_name = model.names[class_id]

                # Increment count for the current frame
                current_frame_object_counts[class_name] += 1
                
                label = f"{class_name} {conf:.2f}"
                track_id_for_this_object = None

                if track_ids_data is not None: # Ensure track IDs exist
                    track_id_for_this_object = track_ids_data[i]
                    
                    # Add track ID to label ONLY if it's the CLASS_TO_TRACK_EXCLUSIVELY
                    if class_name == CLASS_TO_TRACK_EXCLUSIVELY:
                        label = f"ID:{track_id_for_this_object} {class_name} {conf:.2f}"
                        if track_id_for_this_object not in seen_box_track_ids:
                            seen_box_track_ids.add(track_id_for_this_object)
                            total_unique_tracked_boxes += 1
                    
                    # For overall summary, count any tracked object once
                    if track_id_for_this_object not in overall_seen_track_ids:
                        overall_objects_summary[class_name] = overall_objects_summary.get(class_name, 0) + 1
                        overall_seen_track_ids.add(track_id_for_this_object)


                # --- Visuals: Bounding box for all ---
                box_color = (0, 255, 0) # Default Green
                if class_name == "box_broken":
                    box_color = (0,0,255) # Red
                elif class_name == "open_package":
                    box_color = (0,165,255) # Orange
                elif class_name == "forklift":
                    box_color = (255,0,0) # Blue
                elif class_name == "pallets":
                    box_color = (255,255,0) # Yellow
                elif class_name == "person":
                    box_color = (128,0,128) # Purple
                elif class_name == CLASS_TO_TRACK_EXCLUSIVELY: # Ensure tracked box has a distinct color if not already set
                     box_color = (0, 255, 0) # Green for tracked boxes

                cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), box_color, 2)
                cv2.putText(annotated_frame, label, (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, box_color, 2)
        
        # Display current frame object counts
        y_offset = 30
        cv2.putText(annotated_frame, f"Frame: {frame_count}",
                    (10, y_offset), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2) # White text
        y_offset += 25
        for cls_name_txt, count_txt in current_frame_object_counts.items():
            if count_txt > 0: # Only display if count > 0
                cv2.putText(annotated_frame, f"{cls_name_txt}: {count_txt}",
                            (10, y_offset), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2) # Yellow text
                y_offset += 25

        if writer:
            writer.write(annotated_frame)

        cv2.imshow(f'Warehouse Tracking (Tracking IDs for "{CLASS_TO_TRACK_EXCLUSIVELY}" only)', annotated_frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

        if frame_count % 100 == 0:
            print(f"Processed {frame_count} frames. Unique '{CLASS_TO_TRACK_EXCLUSIVELY}' count: {total_unique_tracked_boxes}. Current frame counts: {current_frame_object_counts}")

    cap.release()
    if writer:
        writer.release()
    cv2.destroyAllWindows()

    print(f"\n🎉 Video processing complete!")
    print(f"📝 Total frames processed: {frame_count}")
    print(f"📦 Total unique '{CLASS_TO_TRACK_EXCLUSIVELY}' objects tracked: {total_unique_tracked_boxes}")
    print(f"📊 Overall summary of unique objects (any class with track ID) detected: {overall_objects_summary}")
    
    return total_unique_tracked_boxes, overall_objects_summary

# %%
# --- Usage Example ---
if __name__ == "__main__":
    print(f"🚀 Warehouse Video Detection (Selective Tracking for '{CLASS_TO_TRACK_EXCLUSIVELY}') System Ready!")
    print("\n📝 Usage:")
    print("1. Process video and display: detect_and_selectively_track_video('your_video.mp4')")
    print("2. Process and save output: detect_and_selectively_track_video('input.mp4', 'output_tracked.mp4')")

    # --- CONFIGURE YOUR VIDEO PATH HERE ---
    # video_input_path = r'E:\your_path_to_video\your_warehouse_video.mp4' # Example Windows path
    video_input_path = r'E:\elevatetrsest\CamEDGE counting\test\test3_warehouse.mp4' # REPLACE THIS
    video_output_path = r'E:\elevatetrsest\CamEDGE counting\tracking_output\output3.mp4' # REPLACE THIS (OPTIONAL)

    if video_input_path == r'path_to_your_warehouse_video.mp4': # Check if placeholder is still there
        print("\n⚠️ PLEASE UPDATE 'video_input_path' in the script with your actual video file path.")
    else:
        try:
            print(f"\nProcessing video: {video_input_path}")
            # Example: Process and display only
            unique_boxes, overall_summary = detect_and_selectively_track_video(video_input_path, conf_threshold=0.4)
            
            # Example: Process and save
            # unique_boxes, overall_summary = detect_and_selectively_track_video(video_input_path, video_output_path, conf_threshold=0.4)
            
            print(f"\nFinal count of unique '{CLASS_TO_TRACK_EXCLUSIVELY}' objects: {unique_boxes}")
            # print(f"Final overall summary of unique objects: {overall_summary}")

        except FileNotFoundError:
            print(f"ERROR: Video file not found at '{video_input_path}'. Please check the path.")
        except Exception as e:
            print(f"An error occurred: {e}")
            print("Ensure your video path is correct and OpenCV and Ultralytics are installed properly.")
# Out:
# 🚀 Warehouse Video Detection (Selective Tracking for 'box') System Ready!
#
# 📝 Usage:
# 1. Process video and display: detect_and_selectively_track_video('your_video.mp4')
# 2. Process and save output: detect_and_selectively_track_video('input.mp4', 'output_tracked.mp4')
#
# Processing video: E:\elevatetrsest\CamEDGE counting\test\test3_warehouse.mp4
# Processed 100 frames. Unique 'box' count: 5. Current frame counts: {'box': 2, 'box_broken': 0, 'forklift': 1, 'open_package': 0, 'package': 0, 'pallets': 0, 'person': 0}
# Processed 200 frames. Unique 'box' count: 7. Current frame counts: {'box': 1, 'box_broken': 0, 'forklift': 0, 'open_package': 0, 'package': 0, 'pallets': 0, 'person': 0}
# Processed 300 frames. Unique 'box' count: 7. Current frame counts: {'box': 0, 'box_broken': 0, 'forklift': 0, 'open_package': 0, 'package': 0, 'pallets': 0, 'person': 1}
# Processed 400 frames. Unique 'box' count: 14. Current frame counts: {'box': 1, 'box_broken': 0, 'forklift': 1, 'open_package': 0, 'package': 0, 'pallets': 0, 'person': 0}
# Processed 500 frames. Unique 'box' count: 17. Current frame counts: {'box': 2, 'box_broken': 0, 'forklift': 0, 'open_package': 0, 'package': 0, 'pallets': 0, 'person': 0}
# Processed 600 frames. Unique 'box' count: 19. Current frame counts: {'box': 4, 'box_broken': 0, 'forklift': 0, 'open_package': 0, 'package': 0, 'pallets': 0, 'person': 0}
# End of video or error reading frame.
#
# 🎉 Video processing complete!
# 📝 Total frames processed: 633
# 📦 Total unique 'box' objects tracked: 20
# 📊 Overall summary of unique objects (any class with track ID) detected: {'box': 20, 'box_broken': 0, 'forklift': 8, 'open_package': 0, 'package': 0, 'pallets': 0, 'person': 3}
#
# Final count of unique 'box' objects: 20

# %% [markdown]
# object tracking (only box) + centroid and tail

# %%
# import cv2
# from ultralytics import YOLO
# import numpy as np
# from collections import deque

# # Load your trained model
# model = YOLO(r'E:\elevatetrsest\CamEDGE counting\bestv2.pt') # Use your model path

# # Define the classes your model was trained on
# CLASSES = ['box', 'box_broken', 'forklift', 'open_package', 'package', 'pallets', 'person']
# TARGET_TRACK_CLASS = 'box' # Class to apply special tracking visuals

# # Store history of centroids for tail
# # Format: {track_id: deque([(x1,y1), (x2,y2), ...])}
# track_history = {}
# TAIL_LENGTH = 30  # Number of frames for the tail

# def detect_and_track_warehouse_video(video_path, output_path=None, conf_threshold=0.5, tracker_config="bytetrack.yaml"):
#     """
#     Detect objects, specifically track "box" class with centroid and tail.
#     Counts other objects per frame as well.

#     Args:
#         video_path: Path to input video
#         output_path: Path to save output video (optional)
#         conf_threshold: Confidence threshold for detections
#         tracker_config: Path to the tracker configuration file
#     """
#     global track_history # Use the global track_history

#     cap = cv2.VideoCapture(video_path)
#     writer = None

#     if output_path:
#         fps = int(cap.get(cv2.CAP_PROP_FPS))
#         width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
#         height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
#         fourcc = cv2.VideoWriter_fourcc(*'mp4v')
#         writer = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

#     frame_count = 0
#     # Summary for all unique items based on first appearance (can be adapted if needed)
#     total_detections_summary = {class_name: 0 for class_name in CLASSES}
#     tracked_ids_ever_seen = set()

#     while True:
#         ret, frame = cap.read()
#         if not ret:
#             print("End of video or error reading frame.")
#             break
#         frame_count += 1
#         annotated_frame = frame.copy()

#         # Run detection AND tracking
#         results = model.track(frame, conf=conf_threshold, persist=True, tracker=tracker_config, verbose=False)

#         current_frame_detections_count = {class_name: 0 for class_name in CLASSES}

#         if results[0].boxes is not None and results[0].boxes.id is not None:
#             boxes_data = results[0].boxes.xyxy.cpu().numpy()
#             confs_data = results[0].boxes.conf.cpu().numpy()
#             class_ids_data = results[0].boxes.cls.cpu().numpy().astype(int)
#             track_ids_data = results[0].boxes.id.cpu().numpy().astype(int)

#             for i in range(len(boxes_data)):
#                 x1, y1, x2, y2 = map(int, boxes_data[i])
#                 conf = confs_data[i]
#                 class_id = class_ids_data[i]
#                 track_id = track_ids_data[i]
#                 class_name = model.names[class_id]

#                 # Count all detected objects for the current frame
#                 current_frame_detections_count[class_name] += 1

#                 # Update total unique detections summary for all classes
#                 # This counts any object with a track ID once
#                 if track_id not in tracked_ids_ever_seen:
#                     total_detections_summary[class_name] = total_detections_summary.get(class_name, 0) + 1
#                     tracked_ids_ever_seen.add(track_id)

#                 # --- Visuals: Bounding box for all, special tracking for TARGET_TRACK_CLASS ---
#                 box_color = (0, 255, 0) # Default Green
#                 if class_name == "box_broken":
#                     box_color = (0,0,255) # Red
#                 elif class_name == "open_package":
#                     box_color = (0,165,255) # Orange
#                 elif class_name == "forklift":
#                     box_color = (255,0,0) # Blue
#                 elif class_name == "pallets":
#                     box_color = (255,255,0) # Yellow
#                 elif class_name == "person":
#                     box_color = (128,0,128) # Purple


#                 if class_name == TARGET_TRACK_CLASS:
#                     # Calculate centroid
#                     cx = (x1 + x2) // 2
#                     cy = (y1 + y2) // 2

#                     # Update track history
#                     if track_id not in track_history:
#                         track_history[track_id] = deque(maxlen=TAIL_LENGTH)
#                     track_history[track_id].append((cx, cy))

#                     # Draw centroid
#                     cv2.circle(annotated_frame, (cx, cy), 5, box_color, -1) # Solid circle

#                     # Draw tail
#                     for j in range(1, len(track_history[track_id])):
#                         if track_history[track_id][j - 1] is None or track_history[track_id][j] is None:
#                             continue
#                         thickness = int(np.sqrt(TAIL_LENGTH / float(j + 1)) * 2.0) # Tail gets thinner
#                         cv2.line(annotated_frame, track_history[track_id][j - 1], track_history[track_id][j], box_color, thickness)
                    
#                     # Label for the tracked "box" with ID
#                     label = f"ID:{track_id} {class_name}"
#                     cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), box_color, 2)
#                     cv2.putText(annotated_frame, label, (x1, y1 - 10),
#                                 cv2.FONT_HERSHEY_SIMPLEX, 0.6, box_color, 2)
#                 else:
#                     # Draw standard bounding box and label for other classes (no ID or tail)
#                     label = f"{class_name} {conf:.2f}"
#                     cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), box_color, 2)
#                     cv2.putText(annotated_frame, label, (x1, y1 - 10),
#                                 cv2.FONT_HERSHEY_SIMPLEX, 0.6, box_color, 2)
#         else:
#             # No detections or no track IDs in this frame
#             pass # annotated_frame remains the current frame


#         # Display current frame counts
#         y_offset = 30
#         cv2.putText(annotated_frame, f"Frame: {frame_count}",
#                     (10, y_offset), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)
#         y_offset += 25
#         for cls_name_txt, count_txt in current_frame_detections_count.items():
#             if count_txt > 0:
#                 cv2.putText(annotated_frame, f"{cls_name_txt}: {count_txt}",
#                             (10, y_offset), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2)
#                 y_offset += 25

#         if writer:
#             writer.write(annotated_frame)

#         cv2.imshow('Warehouse Tracking - "box" focus', annotated_frame)
#         if cv2.waitKey(1) & 0xFF == ord('q'):
#             break

#         if frame_count % 100 == 0:
#             active_box_tracks = sum(1 for tid in track_history if model.names[results[0].boxes.cls[np.where(results[0].boxes.id.cpu().numpy() == tid)[0][0]].cpu().numpy().astype(int)] == TARGET_TRACK_CLASS and len(track_history[tid]) > 0)
#             print(f"Processed {frame_count} frames. Current box tracks: {active_box_tracks}. Current frame counts: {current_frame_detections_count}")


#     cap.release()
#     if writer:
#         writer.release()
#     cv2.destroyAllWindows()
#     track_history.clear() # Clear history for next run if function is called again

#     print(f"\n🎉 Video processing complete!")
#     print(f"📝 Total frames processed: {frame_count}")
#     print(f"📊 Summary of unique tracked objects first seen: {total_detections_summary}")

#     return total_detections_summary

# %%
# # --- Usage Example ---
# if __name__ == "__main__":
#     print("🚀 Warehouse Video Detection and 'box' Tracking System Ready!")
#     print("\n📝 Usage:")
#     print("1. Process video and display: detect_and_track_warehouse_video('your_video.mp4')")
#     print("2. Process and save output: detect_and_track_warehouse_video('input.mp4', 'output_tracked.mp4')")

#     # --- CONFIGURE YOUR VIDEO PATH HERE ---
#     # video_input_path = r'E:\your_path_to_video\your_warehouse_video.mp4'
#     video_input_path = r'E:\elevatetrsest\CamEDGE counting\test\test3_warehouse.mp4' # REPLACE THIS
#     video_output_path = r'E:\elevatetrsest\CamEDGE counting\tracking_output\output3.mp4' # REPLACE THIS (OPTIONAL)

#     if video_input_path == r'path_to_your_warehouse_video.mp4':
#         print("\n⚠️ PLEASE UPDATE 'video_input_path' in the script with your actual video file path.")
#     else:
#         try:
#             print(f"\nProcessing video: {video_input_path}")
#             # Example: Process and save
#             # detections_summary = detect_and_track_warehouse_video(video_input_path, video_output_path, conf_threshold=0.4)
            
#             # Example: Process and display only
#             detections_summary = detect_and_track_warehouse_video(video_input_path, conf_threshold=0.4)
#             print("\nFinal Summary of Unique Objects Detected:")
#             print(detections_summary)
#         except Exception as e:
#             print(f"An error occurred: {e}")
#             print("Ensure your video path is correct and OpenCV and Ultralytics are installed properly.")
# Out:
# 🚀 Warehouse Video Detection and 'box' Tracking System Ready!
#
# 📝 Usage:
# 1. Process video and display: detect_and_track_warehouse_video('your_video.mp4')
# 2. Process and save output: detect_and_track_warehouse_video('input.mp4', 'output_tracked.mp4')
#
# Processing video: E:\elevatetrsest\CamEDGE counting\test\test3_warehouse.mp4
# An error occurred: index 0 is out of bounds for axis 0 with size 0
# Ensure your video path is correct and OpenCV and Ultralytics are installed properly.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
